# %%
from google.genai import types
from google.adk.agents import Agent
from google.adk.models.lite_llm import LiteLlm
from prompt import (
    TRAVEL_ADVISOR_DESCRIPTION,
    TRAVEL_ADVISOR_INSTRUCTION,
)
from google.adk.tools.tool_context import ToolContext
from google.adk.sessions import InMemorySessionService, DatabaseSessionService, VertexAiSessionService
from google.adk.runners import Runner

db_url = "sqlite:///./my_session.db"
session_service = DatabaseSessionService(db_url=db_url)

session = await session_service.create_session(
    app_name="travel_advisor",
    user_id="user_1",
    state={
        "user_name" : "성식"
    }
)



MODEL = LiteLlm(model="openai/gpt-4o")


async def get_weather(tool_context: ToolContext, location: str):
    """Get current weather information for a location."""
    # Dummy implementation - returns mock data
    return {
        "location": location,
        "temperature": "22°C",
        "condition": "Partly cloudy",
        "humidity": "65%",
        "wind": "12 km/h",
        "forecast": "Mild weather with occasional clouds expected throughout the day",
    }


async def get_exchange_rate(
    tool_context: ToolContext, from_currency: str, to_currency: str, amount: float
):
    """Get exchange rate between two currencies.
    Args should always be from_currency str, to_currency str, amount flot
    """
    # Dummy implementation - returns mock data
    mock_rates = {
        ("USD", "EUR"): 0.92,
        ("USD", "GBP"): 0.79,
        ("USD", "JPY"): 149.50,
        ("USD", "KRW"): 1325.00,
        ("EUR", "USD"): 1.09,
        ("EUR", "GBP"): 0.86,
        ("GBP", "USD"): 1.27,
        ("JPY", "USD"): 0.0067,
        ("KRW", "USD"): 0.00075,
    }

    rate = mock_rates.get((from_currency, to_currency), 1.0)
    converted_amount = amount * rate

    return {
        "from_currency": from_currency,
        "to_currency": to_currency,
        "amount": amount,
        "exchange_rate": rate,
        "converted_amount": converted_amount,
        "timestamp": "2024-03-15 10:30:00 UTC",
    }


async def get_local_attractions(
    tool_context: ToolContext, location: str, category: str = "all"
):
    """Get popular attractions and points of interest for a location."""
    # Dummy implementation - returns mock data
    attractions = {
        "Paris": [
            {
                "name": "Eiffel Tower",
                "type": "landmark",
                "rating": 4.8,
                "description": "Iconic iron lattice tower",
            },
            {
                "name": "Louvre Museum",
                "type": "museum",
                "rating": 4.7,
                "description": "World's largest art museum",
            },
            {
                "name": "Arc de Triomphe",
                "type": "monument",
                "rating": 4.6,
                "description": "Historic triumphal arch",
            },
            {
                "name": "Notre-Dame",
                "type": "cathedral",
                "rating": 4.5,
                "description": "Medieval Catholic cathedral",
            },
            {
                "name": "Sacré-Cœur",
                "type": "basilica",
                "rating": 4.4,
                "description": "Romano-Byzantine basilica",
            },
        ],
        "Tokyo": [
            {
                "name": "Tokyo Tower",
                "type": "landmark",
                "rating": 4.5,
                "description": "Communications and observation tower",
            },
            {
                "name": "Senso-ji",
                "type": "temple",
                "rating": 4.6,
                "description": "Ancient Buddhist temple",
            },
            {
                "name": "Shibuya Crossing",
                "type": "landmark",
                "rating": 4.4,
                "description": "Busiest pedestrian crossing",
            },
            {
                "name": "Meiji Shrine",
                "type": "shrine",
                "rating": 4.7,
                "description": "Shinto shrine dedicated to Emperor Meiji",
            },
            {
                "name": "Tokyo Skytree",
                "type": "tower",
                "rating": 4.6,
                "description": "Broadcasting and observation tower",
            },
        ],
        "default": [
            {
                "name": "City Center",
                "type": "area",
                "rating": 4.2,
                "description": "Main downtown area",
            },
            {
                "name": "Historical Museum",
                "type": "museum",
                "rating": 4.3,
                "description": "Local history and culture",
            },
            {
                "name": "Central Park",
                "type": "park",
                "rating": 4.1,
                "description": "Main public park",
            },
            {
                "name": "Old Town",
                "type": "district",
                "rating": 4.4,
                "description": "Historic district with traditional architecture",
            },
            {
                "name": "Local Market",
                "type": "market",
                "rating": 4.0,
                "description": "Traditional local marketplace",
            },
        ],
    }

    location_attractions = attractions.get(location, attractions["default"])

    if category != "all":
        location_attractions = [
            a for a in location_attractions if a["type"] == category
        ]

    return {
        "location": location,
        "category": category,
        "attractions": location_attractions,
        "total_count": len(location_attractions),
    }


travel_advisor_agent = Agent(
    name="TravelAdvisorAgent",
    description=TRAVEL_ADVISOR_DESCRIPTION,
    instruction=TRAVEL_ADVISOR_INSTRUCTION,
    tools=[
        get_weather,
        get_exchange_rate,
        get_local_attractions,
    ],
    output_key="travle_advice",
    model=MODEL,
)


runner = Runner(    
    agent=travel_advisor_agent,
    session_service=session_service,
    app_name="travel_advisor",    
)

message = types.Content(role="user", parts=[types.Part(text="안녕. 내 이름이 뭔가요?")])


async for event in runner.run_async(user_id="user_1", session_id=session.id, new_message=message):
    print(event)

    if event.is_final_response():
        print(event.content)
    else:
        print(event.get_function_calls())
        print(event.get_function_responses())
# Out:
# Default value is not supported in function declaration schema for Google AI.
# Default value is not supported in function declaration schema for Google AI.
# content=Content(
#   parts=[
#     Part(
#       function_call=FunctionCall(
#         args={
#           'location': 'Vietnam'
#         },
#         id='call_X1K5Lxd4rdPx1fJUEqjDbEaw',
#         name='get_weather'
#       )
#     ),
#     Part(
#       function_call=FunctionCall(
#         args={
#           'category': 'popular',
#           'location': 'Vietnam'
#         },
#         id='call_CQZVtCvTglN9kgk2BQb08bM3',
#         name='get_local_attractions'
#       )
#     ),
#     Part(
#       function_call=FunctionCall(
#         args={
#           'amount': 1,
#           'from_currency': 'USD',
#           'to_currency': 'VND'
#         },
#         id='call_z2b9oIEXks8jtjjepQ34JQZU',
#         name='get_exchange_rate'
#       )
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=False turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=76,
#   prompt_token_count=414,
#   total_token_count=490
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None invocation_id='e-5dad82c6-27ff-4ddb-9888-fbe1a3c7a969' author='TravelAdvisorAgent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None) long_running_tool_ids=set() branch=None id='574160eb-fe98-47a1-b515-caa598dc1e9a' timestamp=1760258663.355054
# [FunctionCall(
#   args={
#     'location': 'Vietnam'
#   },
#   id='call_X1K5Lxd4rdPx1fJUEqjDbEaw',
#   name='get_weather'
# ), FunctionCall(
#   args={
#     'category': 'popular',
#     'location': 'Vietnam'
#   },
#   id='call_CQZVtCvTglN9kgk2BQb08bM3',
#   name='get_local_attractions'
# ), FunctionCall(
#   args={
#     'amount': 1,
#     'from_currency': 'USD',
#     'to_currency': 'VND'
#   },
#   id='call_z2b9oIEXks8jtjjepQ34JQZU',
#   name='get_exchange_rate'
# )]
# []
# content=Content(
#   parts=[
#     Part(
#       function_response=FunctionResponse(
#         id='call_X1K5Lxd4rdPx1fJUEqjDbEaw',
#         name='get_weather',
#         response=<dict len=6>
#       )
#     ),
#     Part(
#       function_response=FunctionResponse(
#         id='call_CQZVtCvTglN9kgk2BQb08bM3',
#         name='get_local_attractions',
#         response={
#           'attractions': [],
#           'category': 'popular',
#           'location': 'Vietnam',
#           'total_count': 0
#         }
#       )
#     ),
#     Part(
#       function_response=FunctionResponse(
#         id='call_z2b9oIEXks8jtjjepQ34JQZU',
#         name='get_exchange_rate',
#         response=<dict len=6>
#       )
#     ),
#   ],
#   role='user'
# ) grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None invocation_id='e-5dad82c6-27ff-4ddb-9888-fbe1a3c7a969' author='TravelAdvisorAgent' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None) long_running_tool_ids=None branch=None id='7c7fab9a-2cdc-4ead-a2e1-ad22425c733e' timestamp=1760258664.632415
# []
# [FunctionResponse(
#   id='call_X1K5Lxd4rdPx1fJUEqjDbEaw',
#   name='get_weather',
#   response=<dict len=6>
# ), FunctionResponse(
#   id='call_CQZVtCvTglN9kgk2BQb08bM3',
#   name='get_local_attractions',
#   response={
#     'attractions': [],
#     'category': 'popular',
#     'location': 'Vietnam',
#     'total_count': 0
#   }
# ), FunctionResponse(
#   id='call_z2b9oIEXks8jtjjepQ34JQZU',
#   name='get_exchange_rate',
#   response=<dict len=6>
# )]
# content=Content(
#   parts=[
#     Part(
#       text="""베트남 여행에 대한 정보를 알려드리겠습니다, 사용자!
#
# ### 날씨 정보
# - **현재 날씨**: 22°C, 부분적으로 흐림
# - **습도**: 65%
# - **바람**: 12 km/h
# - **예보**: 온화한 날씨, 가끔 구름이 낀 날씨가 예상됩니다.
#
# ### 인기 명소
# - 현재 데이터로는 베트남의 인기 명소 리스트를 제공하지 못하고 있습니다. 다른 출처에서 확인하거나 현지의 관광 웹사이트를 참고하시는 것도 좋을 것 같습니다.
#
# ### 환율 정보
# - **1 USD**는 약 **23,000 VND** (베트남 동) 입니다.
#
# 추가로 궁금한 사항이나 도움이 필요하시면 언제든지 말씀해 주세요! 😊"""
#     ),
#   ],
#   role='model'
# ) grounding_metadata=None partial=False turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=176,
#   prompt_token_count=637,
#   total_token_count=813
# ) live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None invocation_id='e-5dad82c6-27ff-4ddb-9888-fbe1a3c7a969' author='TravelAdvisorAgent' actions=EventActions(skip_summarization=None, state_delta={'travle_advice': '베트남 여행에 대한 정보를 알려드리겠습니다, 사용자!\n\n### 날씨 정보\n- **현재 날씨**: 22°C, 부분적으로 흐림\n- **습도**: 65%\n- **바람**: 12 km/h\n- **예보**: 온화한 날씨, 가끔 구름이 낀 날씨가 예상됩니다.\n\n### 인기 명소\n- 현재 데이터로는 베트남의 인기 명소 리스트를 제공하지 못하고 있습니다. 다른 출처에서 확인하거나 현지의 관광 웹사이트를 참고하시는 것도 좋을 것 같습니다.\n\n### 환율 정보\n- **1 USD**는 약 **23,000 VND** (베트남 동) 입니다.\n\n추가로 궁금한 사항이나 도움이 필요하시면 언제든지 말씀해 주세요!\xa0😊'}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction=None) long_running_tool_ids=None branch=None id='53e59849-29a9-4a58-b08f-b41424f16e06' timestamp=1760258664.643622
# parts=[Part(
#   text="""베트남 여행에 대한 정보를 알려드리겠습니다, 사용자!
#
# ### 날씨 정보
# - **현재 날씨**: 22°C, 부분적으로 흐림
# - **습도**: 65%
# - **바람**: 12 km/h
# - **예보**: 온화한 날씨, 가끔 구름이 낀 날씨가 예상됩니다.
#
# ### 인기 명소
# - 현재 데이터로는 베트남의 인기 명소 리스트를 제공하지 못하고 있습니다. 다른 출처에서 확인하거나 현지의 관광 웹사이트를 참고하시는 것도 좋을 것 같습니다.
#
# ### 환율 정보
# - **1 USD**는 약 **23,000 VND** (베트남 동) 입니다.
#
# 추가로 궁금한 사항이나 도움이 필요하시면 언제든지 말씀해 주세요! 😊"""
# )] role='model'
