# %%
from autogen_agentchat.teams import SelectorGroupChat
from autogen_agentchat.agents import AssistantAgent, UserProxyAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.ui import Console

from tools import web_search_tool, save_report_to_md

# %%
model_client = OpenAIChatCompletionClient(
    model="gpt-4o-mini",
)

# %%
research_planner = AssistantAgent(
    "research_planner",
    description="A strategic research coordinator that breaks down complex questions into research subtasks",
    model_client=model_client,
    system_message="""You are a research planning specialist. Your job is to create a focused research plan.

For each research question, create a FOCUSED research plan with:

1. **Core Topics**: 2-3 main areas to investigate
2. **Search Queries**: Create 3-5 specific search queries covering:
   - Latest developments and news
   - Key statistics or data
   - Expert analysis or studies
   - Future outlook

Keep the plan focused and achievable. Quality over quantity.""",
)

research_agent = AssistantAgent(
    "research_agent",
    description="A web research specialist that searches and extracts content",
    tools=[web_search_tool],
    model_client=model_client,
    system_message="""You are a web research specialist. Your job is to conduct focused searches based on the research plan.

RESEARCH STRATEGY:
1. **Execute 3-5 searches** from the research plan
2. **Extract key information** from the results:
   - Main facts and statistics
   - Recent developments
   - Expert opinions
   - Important context

3. **Quality focus**:
   - Prioritize authoritative sources
   - Look for recent information (within 2 years)
   - Note diverse perspectives

After completing the searches from the plan, summarize what you found. Your goal is to gather 5-10 quality sources.""",
)

research_analyst = AssistantAgent(
    "research_analyst",
    description="An expert analyst that creates research reports",
    model_client=model_client,
    system_message="""You are a research analyst. Create a comprehensive report from the gathered research.

CREATE A RESEARCH REPORT with:

## Executive Summary
- Key findings and conclusions
- Main insights

## Background & Current State
- Current landscape
- Recent developments
- Key statistics and data

## Analysis & Insights
- Main trends
- Different perspectives
- Expert opinions

## Future Outlook
- Emerging trends
- Predictions
- Implications

## Sources
- List all sources used

Write a clear, well-structured report based on the research gathered. End with "REPORT_COMPLETE" when finished.""",
)

quality_reviewer = AssistantAgent(
    "quality_reviewer",
    description="A quality assurance specialist that evaluates research completeness and accuracy",
    tools=[save_report_to_md],
    model_client=model_client,
    system_message="""You are a quality reviewer. Your job is to check if the research analyst has produced a complete research report.

Look for:
- A comprehensive research report from the research analyst that ends with "REPORT_COMPLETE"
- The research question is fully answered
- Sources are cited and reliable
- The report includes summary, key information, analysis, and sources

When you see a complete research report that ends with "REPORT_COMPLETE":
1. First, use the save_report_to_md tool to save the report to report.md
2. Then say: "The research is complete. The report has been saved to report.md. Please review the report and let me know if you approve it or need additional research."

If the research analyst has NOT yet created a complete report, tell them to create one now.""",
)

research_enhancer = AssistantAgent(
    "research_enhancer",
    description="A specialist that identifies critical gaps only",
    model_client=model_client,
    system_message="""You are a research enhancement specialist. Your job is to identify ONLY CRITICAL gaps.

Review the research and ONLY suggest additional searches if there are MAJOR gaps like:
- Completely missing recent developments (last 6 months)
- No statistics or data at all
- Missing a crucial perspective that was specifically asked for

If the research covers the basics reasonably well, say: "The research is sufficient to proceed with the report."

Only suggest 1-2 additional searches if absolutely necessary. We prioritize getting a good report done rather than perfect coverage.""",
)

user_proxy = UserProxyAgent(
    "user_proxy",
    description="Human reviewer who can request additional research or approve final results",
    input_func=input,
)

# %%
selector_prompt = """
Choose the best agent for the current task based on the conversation history:

{roles}

Current conversation:
{history}

Available agents:
- research_planner: Plan the research approach (ONLY at the start)
- research_agent: Search for and extract content from web sources (after planning)
- research_enhancer: Identify CRITICAL gaps only (use sparingly)
- research_analyst: Write the final research report
- quality_reviewer: Check if a complete report exists
- user_proxy: Ask the human for feedback

WORKFLOW:
1. If no planning done yet → select research_planner
2. If planning done but no research → select research_agent  
3. After research_agent completes initial searches → select research_enhancer ONCE
4. If enhancer says "sufficient to proceed" → select research_analyst
5. If enhancer suggests critical searches → select research_agent ONCE more then research_analyst
6. If research_analyst said "REPORT_COMPLETE" → select quality_reviewer
7. If quality_reviewer asked for user feedback → select user_proxy

IMPORTANT: After research_agent has searched 2 times maximum, proceed to research_analyst regardless.

Pick the agent that should work next based on this workflow."""

# %%
text_termination = TextMentionTermination("APPROVED")
max_message_termination = MaxMessageTermination(max_messages=50)
termination_condition = text_termination | max_message_termination

team = SelectorGroupChat(
    participants=[
        research_agent,
        research_analyst,
        research_enhancer,
        research_planner,
        quality_reviewer,
        user_proxy,
    ],
    selector_prompt=selector_prompt,
    model_client=model_client,
    # allow_repeated_speaker=True,
    termination_condition=termination_condition,
)

# %%
await Console(
    team.run_stream(task="오늘은 2025년 9월 30일 입니다. 최근 카카오톡 업데이트 대한 사용자의 비평과 카카오톡의 대응을 조사해주세요. 한글로 작성해줘"),
)
# Out:
# ---------- TextMessage (user) ----------
# 오늘은 2025년 9월 30일 입니다. 최근 카카오톡 업데이트 대한 사용자의 비평과 카카오톡의 대응을 조사해주세요. 한글로 작성해줘
# ---------- TextMessage (research_planner) ----------
# **연구 계획: 카카오톡 업데이트에 대한 사용자 비평 및 카카오톡의 대응 조사**
#
# 1. **핵심 주제**
#    - 최신 카카오톡 업데이트 내용
#    - 사용자 비평 및 반응
#    - 카카오톡의 공식 대응 및 향후 계획
#
# 2. **검색 쿼리**
#    - "2025 카카오톡 업데이트 사용자 비평 최신 동향"
#    - "카카오톡 최신 업데이트 통계 및 사용자 수 변화"
#    - "카카오톡 업데이트에 대한 전문가의 분석 및 리뷰"
#    - "카카오톡 업데이트 이후 사용자 반응과 카카오사의 대응"
#    - "앞으로의 카카오톡 업데이트 방향 및 계획 관련 뉴스"
#
# 이러한 계획을 통해 카카오톡의 최신 업데이트에 대한 사용자 반응과 그에 대한 회사의 대응을 철저히 조사할 수 있습니다.
# ---------- ToolCallRequestEvent (research_agent) ----------
# [FunctionCall(id='call_pkCt4qJV1b2Of0OQP4uJwN4I', arguments='{"query": "2025 카카오톡 업데이트 사용자 비평 최신 동향"}', name='web_search_tool'), FunctionCall(id='call_jBP0CtmufKqNsLusuFfQULN9', arguments='{"query": "카카오톡 최신 업데이트 통계 및 사용자 수 변화"}', name='web_search_tool'), FunctionCall(id='call_r5A5nJdXhljAyUolYiI6zffk', arguments='{"query": "카카오톡 업데이트에 대한 전문가의 분석 및 리뷰"}', name='web_search_tool'), FunctionCall(id='call_EhM4Ay3NZa3YTJgWDGUEVebe', arguments='{"query": "카카오톡 업데이트 이후 사용자 반응과 카카오사의 대응"}', name='web_search_tool'), FunctionCall(id='call_JMrs7mv9DSVeZmKj23R1W46h', arguments='{"query": "앞으로의 카카오톡 업데이트 방향 및 계획 관련 뉴스"}', name='web_search_tool')]
# ---------- ToolCallExecutionEvent (research_agent) ----------
# [FunctionExecutionResult(content='[{\'title\': \'카카오톡 2025년 대개편, 사용자들이 분노한 이유는? : 네이버 블로그\', \'url\': \'https://blog.naver.com/cinews/224021229013?fromRss=true&trackingCode=rss\', \'markdown\': \'카카오톡 2025년 대개편, 사용자들이 분노한 이유는? : 네이버 블로그 블로그 검색이 블로그에서 검색- - - - - - 공감0- - - - - - **블로그 주소 변경 불가 안내**블로그 마켓 판매자의 이력 관리를 위해블로그 주소 변경이 불가합니다. 레이어 닫기!**블로그 아이디가 필요해요!**블로그에서 진짜 나를 기록하고다양한 이웃과 소식을 만나보세요. 지금 시작해볼까요?블로그 아이디 만들기블로그 아이디 만들기 레이어 닫기blog.naver.com/입력 내용 삭제- 설정한 아이디는 나중에 변경할 수 없으니 신중하게 입력해주세요.- 변경 전 공유된 블로그/글/클립 링크는 연결이 끊길 수 있습니다.- **네이버 아이디 또는 개인정보가 포함된 문자 사용** 은 피해주세요.- 블로그 도움말에서 아이디 변경 유의사항을 확인해보세요.나중에 할게요1. 이전 주소로 공유된 글은3개월간 새로운 주소로 연결을 지원하며이후 언제든 연결이 끊길 수 있습니다.2. 블로그 아이디는 한번 변경하면**다시 변경이 불가능** 합니다.**변경하시겠습니까?**취소확인!블로그 아이디는 한번 정하면다시 변경이 불가능합니다.이 아이디로 블로그를 만들까요?취소확인# 환영합니다!    블로그 아이디가 만들어졌어요.!blog.naver.com/바로 시작하기추가정보 입력하기# 기본정보를 입력해주세요.나중에 언제든지 변경할 수 있어요.프로필 이미지 설정지우기사진 업로드- !- !- !- !- !- !- !- !취소적용별명블로그명블로그 주제주제 없음**엔터테인먼트·예술**- 문학·책- 영화- 미술·디자인- 공연·전시- 음악- 드라마- 스타·연예인- 만화·애니- 방송**생활·노하우·쇼핑**- 일상·생각- 육아·결혼- 반려동물- 좋은글·이미지- 패션·미용- 인테리어·DIY- 요리·레시피- 상품리뷰- 원예·재배**취미·여가·여행**- 게임- 스포츠- 사진- 자동차- 취미- 국내여행- 세계여행- 맛집**지식·동향**- IT·컴퓨터- 사회·정치- 건강·의학- 비즈니스·경제- 어학·외국어- 교육·학문**주제없음**- 주제 선택 보류나중에 할게요_기본정보 입력_ _주제 선택_ _이웃 맺기_뒤로가기 버튼# 주제를 선택해 주세요.선택한 주제의 글과 이웃을 추천받을 수 있어요.나중에 할게요_기본정보 입력_ _주제 선택_ _이웃 맺기_뒤로가기 버튼# 인기블로거와 이웃을 맺으세요.이웃을 맺으면 이웃새글에서 글을 받아볼 수 있어요.블로그 시작하기_기본정보 입력_ _주제 선택_ _이웃 맺기_뒤로가기 버튼확인확인이웃추가이웃 - ![]( ![]( ![]( - **사용자 링크**- - !_내정보 보기_ ! 님 - - - _N Pay_    - 네이버톡- **전체 알림**읽은 알림 삭제모두 삭제**알림을 모두 삭제하시겠습니까?**확인취소_레이어 닫기_- - 서비스 더보기나만의 즐겨찾기를 추가해 보세요! **즐겨찾는 서비스**- - - - - - - - - - - - - - - - - - - - - - - ]( 서비스 보기]( 주요 서비스****바로가기 설정** - [ ] 게임- [ ] 날씨- [ ] 네이버+ 스토어- [ ] 네이버캐스트- [ ] 네이버페이 _New_- [ ] 네이버 MYBOX- [ ] 뉴스- [ ] 웹툰- [ ] 메모- [ ] 메일- [ ] 부동산- [ ] 북마크- [ ] 블로그- [ ] 사전- [ ] 스마트보드- [ ] 스포츠- [ ] 시리즈- [ ] 시리즈on- [ ] 오피스- [ ] 웹소설- [ ] 주소록- [ ] 증권(금융)- [ ] 지도- [ ] 지식iN- [ ] 지식백과- [ ] 책- [ ] 카페- [ ] 캘린더- [ ] 네이버TV****- [ ] 국어사전- [ ] 영어/영영사전- [ ] 한자사전- [ ] 일어사전- [ ] 중국어사전- [ ] 프랑스어사전- [ ] 독일어사전- [ ] 러시아어사전- [ ] 베트남어사전- [ ] 스페인어사전- [ ] 파파고**인기/신규서비스**- [ ] 그라폴리오- [ ] 포스트- [ ] 밴드- [ ] 라인- [ ] VIBE _New_- [ ] 프리미엄콘텐츠**확인**취소초기 설정으로 변경* * ** * *|     |     || --- | --- || - ![]( ![]( ![]( ![]( ![]( | - ![]( ![]( ![]( ![]( |블로그 메뉴* * *|     || --- || #  |* * *## blog글쓰기가벼운 글쓰기툴 퀵에디터가 오픈했어요! ]( ]( ](     |     |     || --- | --- | --- ||  |  |  ||     |     |     || --- | --- | --- ||  | ####  39개의 글<br> |  ||     |     |     || --- | --- | --- ||  |  |  ||     |     |     || --- | --- | --- ||  |  |  ||     |     |     || --- | --- | --- ||  | <br>카카오톡 2025년 대개편, 사용자들이 분노한 이유는?<br>]( 22시간 전<br> <br><br><br>]( 카카오톡이 대규모 업데이트를 단행하면서 국민 메신저의 새로운 변화가 시작되었습니다. 하지만 이번 개편에 대한 사용자들의 반응은 예상과 달리 상당히 부정적인데요, 과연 무엇이 문제일까요?<br>\\u200b<br>**🔄 카카오톡 2025년 개편의 핵심 변화사항**<br>**1. 친구 탭의 SNS 피드 전환**<br>가장 논란이 된 변화는 바로 친구 탭의 완전한 변화입니다. 기존의 단순한 친구 목록이 인스타그램이나 페이스북과 같은 **타임라인 피드 형태**로 바뀌었습니다.<br>- 친구들의 프로필 사진 변경 내역 노출<br>  <br>- 상태 메시지 업데이트 알림<br>  <br>- 친구들이 업로드한 사진과 게시물 실시간 표시<br>\\u200b<br>개인적으로 이 부분이 가장 마음에 들지 않습니다.<br>친구 목록에는 있지만 1년에 한 번도 연락하지 않는 무늬만 친구인 사람들의 사진과 게시물을 봐야 하는 게 피곤합니다. → 기존의 친구 탭처럼 볼 수 있는 **선택 메뉴가 추가**되면 좋겠습니다.<br>\\u200b<br>**2. \\\'지금\\\' 탭 신설로 숏폼 콘텐츠 강화**<br>새롭게 추가된 \\\'지금\\\' 탭은 **숏폼 콘텐츠와 오픈채팅 커뮤니티를 통합**하여 실시간 트렌드 소비를 강화했습니다. 틱톡이나 유튜브 쇼츠와 유사한 형태의 콘텐츠를 카카오톡 내에서 바로 즐길 수 있게 되었습니다.<br>\\u200b<br>개인적으로 이용자의 체류 시간은 증가할 수 있겠지만, 반대급부로 \\\'피로도\\\'도 증가할 것 같네요.<br>무엇보다 숏폼만 보는 어린아이를 둔 학부형들은 카카오톡을 대체할 메신저 서비스로 이동할 여지도 있습니다.<br>\\u200b<br>**3. 실용적인 신규 편의 기능들**<br>개편과 함께 사용자 편의성을 높이는 다양한 기능들도 추가되었습니다:<br>- **메시지 수정 기능**: 발송 후 24시간 이내 메시지 수정 가능<br>  <br>- **채팅방 폴더 관리**: 대화방을 카테고리별로 정리<br>  <br>- **보이스 톡 녹음 및 AI 요약**: 음성 통화 내용을 텍스트로 변환하고 요약<br>\\u200b<br>**4. AI 기능 본격 도입**<br>가장 주목받는 변화 중 하나는 **생성형 AI의 본격적인 통합**입니다:<br>- 채팅창에서 바로 사용할 수 있는 AI 검색 기능<br>  <br>- ChatGPT 연동을 통한 고도화된 AI 서비스<br>  <br>- AI 기반 검색 시스템으로 더욱 정확한 정보 제공<br>**\\u200b**<br>]( 사용자들이 분노한 진짜 이유**<br>**프라이버시 침해 우려**<br>가장 큰 불만은 **원치 않는 개인정보 노출**입니다. 직장 동료나 상사의 일상까지 실시간으로 확인해야 하는 상황에  ...
# ---------- ToolCallSummaryMessage (research_agent) ----------
# [{'title': '카카오톡 2025년 대개편, 사용자들이 분노한 이유는? : 네이버 블로그', 'url': 'https://blog.naver.com/cinews/224021229013?fromRss=true&trackingCode=rss', 'markdown': '카카오톡 2025년 대개편, 사용자들이 분노한 이유는? : 네이버 블로그 블로그 검색이 블로그에서 검색- - - - - - 공감0- - - - - - **블로그 주소 변경 불가 안내**블로그 마켓 판매자의 이력 관리를 위해블로그 주소 변경이 불가합니다. 레이어 닫기!**블로그 아이디가 필요해요!**블로그에서 진짜 나를 기록하고다양한 이웃과 소식을 만나보세요. 지금 시작해볼까요?블로그 아이디 만들기블로그 아이디 만들기 레이어 닫기blog.naver.com/입력 내용 삭제- 설정한 아이디는 나중에 변경할 수 없으니 신중하게 입력해주세요.- 변경 전 공유된 블로그/글/클립 링크는 연결이 끊길 수 있습니다.- **네이버 아이디 또는 개인정보가 포함된 문자 사용** 은 피해주세요.- 블로그 도움말에서 아이디 변경 유의사항을 확인해보세요.나중에 할게요1. 이전 주소로 공유된 글은3개월간 새로운 주소로 연결을 지원하며이후 언제든 연결이 끊길 수 있습니다.2. 블로그 아이디는 한번 변경하면**다시 변경이 불가능** 합니다.**변경하시겠습니까?**취소확인!블로그 아이디는 한번 정하면다시 변경이 불가능합니다.이 아이디로 블로그를 만들까요?취소확인# 환영합니다!    블로그 아이디가 만들어졌어요.!blog.naver.com/바로 시작하기추가정보 입력하기# 기본정보를 입력해주세요.나중에 언제든지 변경할 수 있어요.프로필 이미지 설정지우기사진 업로드- !- !- !- !- !- !- !- !취소적용별명블로그명블로그 주제주제 없음**엔터테인먼트·예술**- 문학·책- 영화- 미술·디자인- 공연·전시- 음악- 드라마- 스타·연예인- 만화·애니- 방송**생활·노하우·쇼핑**- 일상·생각- 육아·결혼- 반려동물- 좋은글·이미지- 패션·미용- 인테리어·DIY- 요리·레시피- 상품리뷰- 원예·재배**취미·여가·여행**- 게임- 스포츠- 사진- 자동차- 취미- 국내여행- 세계여행- 맛집**지식·동향**- IT·컴퓨터- 사회·정치- 건강·의학- 비즈니스·경제- 어학·외국어- 교육·학문**주제없음**- 주제 선택 보류나중에 할게요_기본정보 입력_ _주제 선택_ _이웃 맺기_뒤로가기 버튼# 주제를 선택해 주세요.선택한 주제의 글과 이웃을 추천받을 수 있어요.나중에 할게요_기본정보 입력_ _주제 선택_ _이웃 맺기_뒤로가기 버튼# 인기블로거와 이웃을 맺으세요.이웃을 맺으면 이웃새글에서 글을 받아볼 수 있어요.블로그 시작하기_기본정보 입력_ _주제 선택_ _이웃 맺기_뒤로가기 버튼확인확인이웃추가이웃 - ![]( ![]( ![]( - **사용자 링크**- - !_내정보 보기_ ! 님 - - - _N Pay_    - 네이버톡- **전체 알림**읽은 알림 삭제모두 삭제**알림을 모두 삭제하시겠습니까?**확인취소_레이어 닫기_- - 서비스 더보기나만의 즐겨찾기를 추가해 보세요! **즐겨찾는 서비스**- - - - - - - - - - - - - - - - - - - - - - - ]( 서비스 보기]( 주요 서비스****바로가기 설정** - [ ] 게임- [ ] 날씨- [ ] 네이버+ 스토어- [ ] 네이버캐스트- [ ] 네이버페이 _New_- [ ] 네이버 MYBOX- [ ] 뉴스- [ ] 웹툰- [ ] 메모- [ ] 메일- [ ] 부동산- [ ] 북마크- [ ] 블로그- [ ] 사전- [ ] 스마트보드- [ ] 스포츠- [ ] 시리즈- [ ] 시리즈on- [ ] 오피스- [ ] 웹소설- [ ] 주소록- [ ] 증권(금융)- [ ] 지도- [ ] 지식iN- [ ] 지식백과- [ ] 책- [ ] 카페- [ ] 캘린더- [ ] 네이버TV****- [ ] 국어사전- [ ] 영어/영영사전- [ ] 한자사전- [ ] 일어사전- [ ] 중국어사전- [ ] 프랑스어사전- [ ] 독일어사전- [ ] 러시아어사전- [ ] 베트남어사전- [ ] 스페인어사전- [ ] 파파고**인기/신규서비스**- [ ] 그라폴리오- [ ] 포스트- [ ] 밴드- [ ] 라인- [ ] VIBE _New_- [ ] 프리미엄콘텐츠**확인**취소초기 설정으로 변경* * ** * *|     |     || --- | --- || - ![]( ![]( ![]( ![]( ![]( | - ![]( ![]( ![]( ![]( |블로그 메뉴* * *|     || --- || #  |* * *## blog글쓰기가벼운 글쓰기툴 퀵에디터가 오픈했어요! ]( ]( ](     |     |     || --- | --- | --- ||  |  |  ||     |     |     || --- | --- | --- ||  | ####  39개의 글<br> |  ||     |     |     || --- | --- | --- ||  |  |  ||     |     |     || --- | --- | --- ||  |  |  ||     |     |     || --- | --- | --- ||  | <br>카카오톡 2025년 대개편, 사용자들이 분노한 이유는?<br>]( 22시간 전<br> <br><br><br>]( 카카오톡이 대규모 업데이트를 단행하면서 국민 메신저의 새로운 변화가 시작되었습니다. 하지만 이번 개편에 대한 사용자들의 반응은 예상과 달리 상당히 부정적인데요, 과연 무엇이 문제일까요?<br>\u200b<br>**🔄 카카오톡 2025년 개편의 핵심 변화사항**<br>**1. 친구 탭의 SNS 피드 전환**<br>가장 논란이 된 변화는 바로 친구 탭의 완전한 변화입니다. 기존의 단순한 친구 목록이 인스타그램이나 페이스북과 같은 **타임라인 피드 형태**로 바뀌었습니다.<br>- 친구들의 프로필 사진 변경 내역 노출<br>  <br>- 상태 메시지 업데이트 알림<br>  <br>- 친구들이 업로드한 사진과 게시물 실시간 표시<br>\u200b<br>개인적으로 이 부분이 가장 마음에 들지 않습니다.<br>친구 목록에는 있지만 1년에 한 번도 연락하지 않는 무늬만 친구인 사람들의 사진과 게시물을 봐야 하는 게 피곤합니다. → 기존의 친구 탭처럼 볼 수 있는 **선택 메뉴가 추가**되면 좋겠습니다.<br>\u200b<br>**2. \'지금\' 탭 신설로 숏폼 콘텐츠 강화**<br>새롭게 추가된 \'지금\' 탭은 **숏폼 콘텐츠와 오픈채팅 커뮤니티를 통합**하여 실시간 트렌드 소비를 강화했습니다. 틱톡이나 유튜브 쇼츠와 유사한 형태의 콘텐츠를 카카오톡 내에서 바로 즐길 수 있게 되었습니다.<br>\u200b<br>개인적으로 이용자의 체류 시간은 증가할 수 있겠지만, 반대급부로 \'피로도\'도 증가할 것 같네요.<br>무엇보다 숏폼만 보는 어린아이를 둔 학부형들은 카카오톡을 대체할 메신저 서비스로 이동할 여지도 있습니다.<br>\u200b<br>**3. 실용적인 신규 편의 기능들**<br>개편과 함께 사용자 편의성을 높이는 다양한 기능들도 추가되었습니다:<br>- **메시지 수정 기능**: 발송 후 24시간 이내 메시지 수정 가능<br>  <br>- **채팅방 폴더 관리**: 대화방을 카테고리별로 정리<br>  <br>- **보이스 톡 녹음 및 AI 요약**: 음성 통화 내용을 텍스트로 변환하고 요약<br>\u200b<br>**4. AI 기능 본격 도입**<br>가장 주목받는 변화 중 하나는 **생성형 AI의 본격적인 통합**입니다:<br>- 채팅창에서 바로 사용할 수 있는 AI 검색 기능<br>  <br>- ChatGPT 연동을 통한 고도화된 AI 서비스<br>  <br>- AI 기반 검색 시스템으로 더욱 정확한 정보 제공<br>**\u200b**<br>]( 사용자들이 분노한 진짜 이유**<br>**프라이버시 침해 우려**<br>가장 큰 불만은 **원치 않는 개인정보 노출**입니다. 직장 동료나 상사의 일상까지 실시간으로 확인해야 하는 상황에 많은 사용자들이 피로감을 호소하고 있습니다.<br>> "상사의 프로필 사진이 바뀔 때마다 알림이 와서 스트레스받아요 ...
# [{'title': '카카오톡 15년 만 대개편: 핵심 변화와 이용자 반응 완전 분석 - Goover', 'url': 'https://seo.goover.ai/report/202509/go-public-report-ko-7291cc3a-e47c-41cf-a6ca-885e417d6f31-0-0.html', 'markdown': '![]( 카카오톡 15년 만 대개편: 핵심 변화와 이용자 반응 완전 분석리뷰 리포트2025년 09월 26일!## 리뷰 포인트- 이번 리포트는 카카오톡의 대규모 업데이트 이유와 주요 기능, 그리고 이용자들의 상반된 반응을 객관적 데이터와 사용자 목소리를 바탕으로 구분해 정리합니다.- 공식 행사 발표 내용과 국내·외 언론 보도, 커뮤니티 반응 자료를 근거로 기능별 변화와 사용자 피드백을 데이터 기반으로 제시했습니다.## 1. 대규모 개편 배경과 전략적 의도- 카카오톡은 15년 간의 역사를 지닌 메신저 서비스에서 최근 대규모 개편을 단행했습니다. 이번 개편은 단순한 기능 개선을 넘어서 카카오톡을 콘텐츠 및 AI 중심의 통합 플랫폼으로 진화시키기 위해 설계되었습니다. 점점 더 감소하는 사용자 체류시간과 젊은 세대의 \'탈카톡\' 현상이 심화됨에 따라, 카카오는 모바일인덱스에서 확인된 바와 같이 2021년 한 사용자 당 월 평균 사용 시간은 822분에서 2023년 7월에는 709분으로 13.8% 감소한 상황에 있습니다. 이는 카카오톡이 소셜 기능과 콘텐츠 중심의 앱으로 변모할 필요성을 제기했습니다.- 카카오톡의 개편은 크게 두 가지 축으로 구성되며, 첫 번째는 친구 탭의 피드 형태 전환입니다. 기존의 전화번호부 기반의 레이아웃에서 친구들의 프로필 업데이트와 생일 정보, 사진·동영상 공유를 포함한 소셜 피드를 제공하는 방식으로 변화하게 됩니다. 두 번째는 오픈채팅 탭을 숏폼 비디오 서비스로 개편하여, 사용자들이 콘텐츠를 소비하고 제작하는 새로운 환경을 마련하려는 것이죠. 이러한 변화는 인스타그램과의 직접적인 경쟁을 염두에 둔 전략으로 보이는데, 국내외 여러 성공적인 플랫폼들이 이미 이러한 방향으로 개편하여 체류 시간을 늘린 사례가 있습니다.- 예를 들어, 인스타그램은 DM 중심의 서비스에서 피드와 릴스를 강화하여 체류 시간이 30~40% 증가했고, 위챗 또한 모먼츠 피드 도입 이후 25% 이상의 체류 시간 상승을 기록했습니다. 카카오는 이러한 선례를 기반으로 피드형 개편이 동일한 효과를 낼 것이라는 희망을 품고 있습니다. 증권가에서는 두 탭이 성공적으로 안착할 경우, 카카오톡의 트래픽이 20% 이상 증가할 수 있으며, 광고 매출도 전년 대비 10% 이상 성장할 것으로 예상하고 있습니다.- 하지만 이러한 변화에 대한 사용자 반응은 예상과 달리 차갑습니다. 특히, 카카오톡의 특성상 가족, 친지, 직장 동료와 연결된 환경에서 인스타그램과 같은 소셜 기능을 즉각적으로 용납하기 어려운 경향이 나타나고 있습니다. 이에 따라, 평균 친구 수는 410명이지만, 월평균 프로필 업데이트 비율은 23%에 불과하다는 통계가 이를 증명합니다. 카카오는 이러한 사용자 기반 변화와 기존 충성 고객을 유지하기 위한 대책이 필요합니다. 최근 개편이 소통 중심의 메신저로서의 가치를 해치지 않도록 조율하는 것이 중요할 것입니다.- 결국 이번 대규모 개편은 카카오톡이 생존을 위해 플랫폼으로 확장하고, AI와 콘텐츠를 활용하여 경쟁력을 높이기 위한 전략의 일환입니다. 카카오는 이러한 변화를 통해 \'AI 대중화\'를 선도하고, 사용자 경험을 개선하려는 의도를 분명히 하고 있지만, 이를 어떻게 이용자들에게 자연스럽게 전달할지에 대한 고심이 깊은 상황입니다.## 2. 핵심 기능 업데이트 요약- 카카오는 최근 KakaoTalk의 사용성과 기능을 대폭 개선하기 위해 대규모 업데이트를 단행했습니다. 이번 업데이트는 온디바이스 AI 기능 탑재, 메시지 수정 기능, 그리고 채팅방 폴더 등의 주요 특징을 포함하고 있습니다. 이러한 기능들은 카카오톡을 단순한 메신저에서 콘텐츠 및 커뮤니티 중심의 통합 플랫폼으로 발전시키는 데 중점을 두고 있습니다.- 첫 번째로, 온디바이스 AI 기능인 \'카나나\'가 도입되어 사용자에게 보다 개인화된 경험을 제공합니다. 사용자가 대화 중 특정 요청을 입력하면 카나나가 자동으로 다음 단계의 작업이나 추천을 제안합니다. 이러한 기능은 사용자들 사이에서 실시간으로 필요한 정보를 제공하고, 여러 복잡한 메뉴를 거치지 않고도 작업을 완료할 수 있는 점에서 호평을 받고 있습니다.- 둘째, 새롭게 추가된 메시지 수정 기능은 사용자가 메시지를 전송한 후 24시간 이내에 내용을 수정할 수 있게 해줍니다. 이 기능은 초기 메시지 전송 후 실수를 수정할 수 있는 가능성을 제공하며, 편리함을 느낀 사용자들로부터 좋은 반응을 얻고 있습니다. Kakao의 데이터에 따르면, 메시지 삭제 기능 사용이 327% 증가했으며, 이는 사용자들이 보다 향상된 유연성을 요구하고 있다는 반증입니다.- 셋째, 새로운 채팅방 폴더 기능은 사용자가 다양한 주제에 따라 채팅방을 정리할 수 있게 해주며, 이로 인해 정보 관리가 한층 수월해졌습니다. 사용자 피드백에 따르면, 이 기능은 긴 대화 목록을 가진 사용자에게 매우 유용하다는 평이 주를 이루고 있습니다.- 마지막으로, 카카오톡은 친구 탭을 소셜 피드 형식으로 전환하는 새로운 ‘지금’ 탭을 도입함으로써 사용자들이 짧은 동영상과 커뮤니티 기능을 누릴 수 있도록 했습니다. 이와 같은 변화는 사용자 유지의 측면에서 중요한 전략으로 여겨지고 있습니다.- 이러한 여러 기능들은 카카오톡이 젊은 세대의 요구에 맞춰 지속적으로 진화하고 있음을 보여줍니다. 다만, 일부 사용자들은 이러한 대규모 변화에 적응하기 어려워하고 있으며, 업데이트의 필요성이 보다 설득력 있게 전달될 필요가 있습니다.## 3. 긍정적 반응: 편의성 강화 평가- 카카오톡의 대규모 개편 후 이용자들의 반응은 긍정적 평과 부정적 평이 엇갈리고 있습니다. 특히, 고급 기능인 메시지 수정 기능이 소개되면서 사용자들은 실수에 대한 재처리를 할 수 있어 편의성이 크게 향상되었다고 평가하고 있습니다. 예를 들어, 업데이트 이후 메시지 삭제 사용률이 327% 증가며, 이는 사용자들이 보다 유연하게 소통을 진행하고 있다는 것을 나타냅니다. 하루 평균 710, 000명의 사용자가 메시지를 전송 후 5분 이상 경과된 메시지를 삭제하는 것으로 나타났습니다. 이러한 반응은 카카오톡이 사용자의 의사소통 방식을 개선하고자 노력하고 있음을 시사합니다.- 반면, 친구 목록의 피드형 전환에 대한 반발은 상당히 큽니다. 많은 사용자들이 카카오톡을 개인적인 메신저로 사용하고 있었기에, 친구의 프로필 변경이나 사생활이 피드 형태로 공개되는 것을 불편하게 느끼고 있습니다. 한 사용자는 "업무용으로 쓰는데 거래처나 집주인 프로필 변동이 화면에 가득 뜨는 게 불편하다"라고 말하며, 이러한 변경이 자신들의 프라이버시를 침해할 수 있다고 우려하고 있습니다. 또한, 카카오톡 사용자 중 월평균 프로필 업데이트 비율이 23%로 저조한 점은 사용자들이 소셜 기능에 대한 관심이 낮고, 기존의 메신저 본연의 가치에 대한 선호를 보이고 있음을 보여줍니다.- 이와 더불어, 자동 업데이트 차단법이 인터넷 커뮤니티에서 확산되고 있는 것은 사용자들의 불만을 더욱 부각시키고 있습니다. 특정 기능이 불편하다며 사용자가 자발적으로 업데이트를 차단하려는 움직임은 카카오의 전략적 결정에 대한 사용자 불만의 반영이라 볼 수 있습니다. 특히, 삼성 갤럭시 사용자들은 구글 플레이스토어에서 \'자동 업데이트 사용\' 체크를 해제하는 방법을 공유하고 있으며, 아이폰 사용자들은 셀룰러 데이터 자동 다운로드를 끄는 방식으로 대처하고 있습니다. 이러한 대응은 사용자들이 업데이트 이후 불편함을 해결하기 위한 적극적인 조치를 취하고 있다는 점에서 주목할 만합니다.- 결론적으로, 최신 카카오톡 업데이트는 기술적 편의성을 제공하는 여러 기능들을 도입하였으나, 변화를 받아들이기 어려운 사용자도 많아 보입니다. 이에 따라, 카카오는 사용자의 피드백을 적극 반영하여, 기존의 메신저 기능과 새로운 소셜 기능 간의 균형을 찾아야 할 것으로 보입니다. 향후 사용자들이 안정적으로 ...
# [{'title': '"1점도 아깝다…카톡, 돌려놔" 비판 쏟아지는 카카오톡 \'롤백\' 나설까', 'url': 'https://news.nate.com/view/20250928n07886', 'markdown': '광고 영역- - - - - - - * * *# "1점도 아깝다…카톡, 돌려놔" 비판 쏟아지는 카카오톡 \'롤백\' 나설까 기사전송 _2025-09-28 11:50_- - 공유하기- 네이트온- 페이스북- 엑스URL복사_AI_ 챗으로 요약- 가 _1_작게- 가 _2_보통- 가 _3_크게- 가 _4_아주크게- 가 _5_가장크게기사 제목과 본문 내용을 자동 요약한 내용입니다.전체 내용을 이해하기 위해서는 기사 본문 전체를 확인하는 것이 더 좋습니다._AI_ 챗이 열심히 분석 중입니다. 잠시만 기다려주세요.|     || --- || |     || --- || ! || 기사 내용 이해를 돕기 위해 AI 이미지 생성기로 만든 사진. 툴 제공 = 챗GPT | |[서울경제]카카오톡이 15년만에 대대적인 개편을 단행한 뒤 구글 플레이스토어와 애플 앱스토어에는 \'1점 리뷰\'가 속출하고 있다. 이용자들은 최저점을 매기며 "업데이트를 되돌려 달라"고 목소리를 높이고 있다.28일 정보통신기술(ICT) 업계에 따르면 UX(사용자경험) 전문기업 피엑스디(PXD)가 사용자 분석 도구 ‘어피니티 버블’을 통해 지난 23일 업데이트 당일 앱 마켓에 등록된 카카오톡 리뷰 1000건을 분석한 결과, 대다수가 “사용자 경험이 저하됐다”고 지적한 것으로 나타났다.주제별로는 업데이트 전반 불만이 42%로 가장 많았으며, UI(사용자환경)·디자인 불만이 19%, 친구 목록과 프로필 관련 불만이 10%를 차지했다. 앱스토어에는 "1점도 아깝다", "역대 최악의 업데이트", "차라리 기본 메신저와 SNS 기능을 나눴으면 좋겠다"는 강한 불만이 이어졌다.ADAD이번 개편으로 기존 \'친구 목록\'이 기본 화면에서 사라지고 프로필 변동 내역이 격자형 피드처럼 표시됐다. 사용자는 탭 상단 버튼을 눌러야만 친구 목록을 볼 수 있다. 이 과정에서 "더 이상 카카오톡을 메신저라 부를 수 없다", "페이스북·인스타그램과 다를 바 없다"는 지적이 이어졌다.일부 이용자는 다른 메신저로의 이동을 고려한다는 의견도 냈다. "숏폼 영상을 원하지 않는데 강제로 노출된다", "피드·숏폼 사용 여부를 선택할 수 있어야 한다"는 요구가 대표적이다. 화면 상 광고 비중이 늘어난 점(6%)도 불만 요인으로 꼽혔다.이용자 불만은 단순한 불편을 넘어 \'카카오톡의 정체성\'에 대한 문제 제기로 번지고 있다. 한 리뷰에는 "대화를 위한 앱이 아니라 수익 창출을 위한 플랫폼으로 변질됐다"는 내용이 담겼다. 또 "업데이트를 롤백할 방법이라도 달라"는 호소도 있었다.시장 반응 역시 부정적이었다. 카카오 주가는 26일 장중 한때 4% 이상 하락하며 6만원 선이 붕괴되기도 했다. 업계에서는 카카오가 다음 개편 때 친구 탭을 조정할 지 주목하고 있다.카카오는 “통상 업데이트 배포 후 약 일주일간 반응을 살핀 뒤 월 단위 업데이트에 이를 반영한다”며 “이용자의 피드백을 경청해 기능을 개선할 예정”이라고 밝혔다.이인애 기자 lia@sedaily.com[서울경제 관련뉴스]- ## - ## - ## - ## - ## - 최고예요4- 훈훈해요0- 어이없어요6- 속상해요3- 화나요657네이트 뉴스**올려** _587_**내려** _4_광고 영역[[IT/과학] 네티즌관심뉴스]( "관심뉴스보기")- 1 - 2 - 3 - 4 - 5 ")- 6 - 7 - 8 [[사이테크+] "항생제가 박테리아 방어막 뚫...]( "[사이테크+] "항생제가 박테리아 방어막 뚫고 침투하는 장면 첫 포착"")- 9 - 10 _[공지]_ 댓글 입력 영역댓글 입력 영역댓글쓰기 0 / 300 자댓글- - - ![]( 댓글숨기기댓글 운영 원칙댓글 운영 원칙 보기**베스트 댓글**!dhfl**** !_|_ 09.28 11:58- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **2,133** **14**! 저게뭐냐 ? 언넘이 뻘짓 했는지 모르겠는데 고집피지말고 원상복구해라 !!! ]( 댓글 8!faye**** !_|_ 09.28 11:59- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **1,934** **9**! 롤백 필요! 원래 시스템 개편되면 불편하다가도 점점 익숙해지기 마련이지만, 이번 카톡 개편은 시각적 공해가 워낙 심하다보니 시간이 지나도 여전히 불편하고 짜증날 것 같네요 ]( 댓글 2!ddae**** !_|_ 09.28 12:01- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **1,743** **18**! 회사가 맛이 갔음. 원래부터 지 멋대로 대표와 그 추종자들. 우르르 몰려다니며 스타트업계 편가르고 잘난척하고 인싸놀이하던 것들이 완전 장악한 회사. 처음엔 착했는데 유명하고 권력을 가지면서 그저 지멋대로 우르르 몰려다니며 페북 등에서 끼리끼리 띄워주며 패거리놀이하는 저질들. ]( 댓글 7- ]( 클린지수 블라인드클린지수 블라인드란?클린지수로 댓글을 필터링해서 볼 수 있습니다. 해당 옵션에 따라 해당 클린지수 이상의 댓글만 보여줍니다.- - 전체- 100- 90↑- 80↑- 70↑- 60↑- 50↑- 40↑- 30↑- 20↑- 10↑|-  |-  |- **일반 댓글**gnrt**** !_|_ 09.29 04:46- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **0** **0**! 상황 파악이 안 되는 정신 줄 놓은 놈들이 아직 탈퇴자 수가 많지 않으니 일단 지켜보자고 하고 있음 ㅋㅋㅋㅋ-> 심리저변에는 자기들이 틀리지 않았음을 믿고 싶은 것임. 다시 말해서 새로운 것에 대한 잠깐의 거부감이 들 뿐, 시간이 지나면서 자연스럽게 해결 될 것이라는 아니, 되길 바라는 마음이라는 것임 ]( 댓글 0kyc-**** !_|_ 09.29 01:32- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **0** **0**! 원래처럼 친구목록만 있는걸 기본으로 두고인스타처럼 피드를 구현하고 싶은거라면 피드 탭은 따로 클릭해서 넘어가도록 따로 빼던지 해라 그리고 생일인 친구도 크기 다시 줄여놓던지 기존처럼 바꿔놓고.친하지도 않은 거래처 직원 생일을 몇일전부터 대체 왜 대문짝하게 봐야하는거냐? 카톡친구라고 다 친구인줄 아나?인스타는 본인이 선택해서 팔로우하기라도 하지.카톡은 업무적인 관계의 사람들이든, 하다못해 종종 주문하는 가게 등 사장님들 번호들도 있는데친구가 아닌사람들의 불특정다수의 생일이며 소식을 내가 왜 대문짝하게 봐야하나. ]( 댓글 0annd**** !_|_ 09.29 00:23- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **0** **0**! ... ]( 댓글 0c101**** !_|_ 09.28 23:57- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **2** **3**카톡 검열 편하게하려고 작업한거 같은데~~~쎄쎄~~~ ]( 댓글 0wngy**** !_|_ 09.28 23:46- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **0** **0**! 티발 원상복구시켜라 카톡 앞으로 안쓰기전에 ]( 댓글 0sabi**** !_|_ 09.28 23:32- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **4** **0**! 카톡 클릭하니., . 우웩! 밥맛떨어지는 면상이 나를 반기며 웃고있노이기야.., 뭔데? ]( 댓글 0bowc**** !_|_ 09.28 23:05- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **0** **4**업데이트 한거 좋던데 왜 지럴들이냐 윤어게인!!!!! ]( 댓글 0didt**** !_|_ 09.28 23:03- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **0** **0**이번 업데이트 책임자는 네이버 라인쪽 스파이가 확실하다 ]( 댓글 0silv**** !_|_ 09.28 22:27- 클린지수 _/_ 100점- 다른댓글보기- 댓글구독하기 **3** **0**! 아후 로그아웃 됐다가 로그인했더니 업데이트버젼으로 되어있네 쓰기가 싫어졌다ㅜ ]( 댓글 0okay**** !_|_ 09.28 22:25- 클린지수 _/ ...
# [{'title': '[뉴스쏙] 카톡 업데이트 "완전 싫어!"…카카오, 개선 방향 발표 / 연합 ...', 'url': 'https://www.youtube.com/watch?v=v4HMe25Z8a0', 'markdown': '!# [[뉴스쏙] 카톡 업데이트 "완전 싫어!"…카카오, 개선 방향 발표 / 연합뉴스TV(YonhapnewsTV)]( Public**Uploaded by**: **Uploaded at**: 2025-09-28T06:01:18-07:00**Published at**: 2025-09-28T06:01:18-07:00**Length**: 01:51:20**Views**: 7271**Likes**: 38**Category**: News & Politics## Description```카카오톡 대개편 이후 이용자들의 혹평이 쏟아지고 1점 리뷰가 속출하자 카카오가 결국 개선 방향을 발표하기로 했습니다. 이용자들은 카카오톡이 메신저 기능에 집중하지 않았다며 이번 업데이트를 강하게 비판했는데요. 예전으로 돌아갈 수 있을까요? 뉴스쏙에서 함께 살펴보시죠.▲"부장님 골프사진 봐야 하나요"…카톡 \'자동 업데이트\' 불만 속출(최덕재 기자)▲"챗GPT 업고 피드형으로"…카톡, 15년 만에 대변신(문형민 기자)▲[경제읽기]대미투자 두고 \'줄다리기\'…바뀐 카카오톡 평가는[출연 : 권혁중 경제평론가]#카카오 #카카오톡 #카톡 #업데이트 #혹평 #망함 #개선방향 #발표 #결국 #메신저 #인스타 #뉴스쏙 #연합뉴스TV ▣ 연합뉴스TV 다큐멘터리 전문 채널 \'다큐디깅\' 구독하기 연합뉴스TV 유튜브 채널 구독 대한민국 뉴스의 시작 연합뉴스TV / Yonhap News TV Transcript카카오톡 업데이트에 대해서 불만을 표출하는 목소리들이 나오고 있습니다. 일부 채팅이 개선됐다는 평가도 있습니다만 변화가 과하단 불만도 허적지 않는데요. 채팅의 영역에서 SNS 영역으로 넘어간 것 아니냐는 건데 카카오도이 부분에 고민이 깊습니다. 최덕자 계좌입니다. 최신 업데이트된 카카오톡을 연이 웬 사진이 큼지막하게 시선을 사로잡습니다. 원한 것도 아닌데 카카오톡 친구의 변경된 프로필 사진이 뜨는 겁니다. 직장 상사나 잘 모르는 사람인 경우도 많아 불편할 수 있는 부분입니다. 현재로선 사진이 이렇게 존재감 있게 등장하는 걸 막을 방법도 마땅찬이다. 온라인 커뮤니티에는 업데이트를 막는 방법을 묻는 글들이 이따라 올라오고 SNS에서도 업데이트를 하지 말라는 조언이 줄습니다. 채팅 플랫폼에 그치지 않고 AI와 SNS를 접목해 변화하겠단 전략이지만 소비자들의 수요 파악이 얼마나 선행됐는지 되물어볼 대목입니다.이 정도 규모의 변화는 카카오톡 역사상 처음 있는 일이라 할 수 있습니다. 시대의 변화에 민첩하게 대응하겠다는 카카오톡의 의지를 담고 있습니다. 반면 필요했던 채팅 기능이 생긴 부분은 있습니다. 오타가 났을 때 쓴 글를 지우지 않아도 수정해 놓을 수 있는 기능이 생겼습니다. 안 읽은 메시지만 모아볼 수 있는 폴더가 생겼고 채 GPT 도입은 긍정적 평가를 얻고 있습니다. 채팅계에서는 일부 긍정적 평가를 받지만 SNS 반영은 부정적인 평가가 줄을 이루면서 카카오는 정체성 무게출을 어디에 둘지 고심하고 있습니다. 카카오 관계자는 목적형 서비스에서 탐색형 서비스로 전환하는 과정이라며 대화를 목적으로 유입된 사용자가 즐길거리나 새로운 정보 같은 새로운 콘텐츠로 이어지게 할 것이라고 설명했습니다. 이어 고객 불만을 접수해 수정해 갈 것이라면서 그동안 카카오톡은 계속 변화해 왔다고 강조했습니다. 연합뉴스 TV 최덕제입니다. 카카오톡이 출시 15년 만에 대변신을 합니다. 채팅에 채 GPT를 탑재하고 인스타그램과 유상한 피드 형식을 도입해서 소셜 커뮤니티 플랫폼으로 영역을 넓힌다는 구상입니다. 경쟁 플랫폼으로 눈을 돌린 이용자들의 마음을 다시 사로잡을 수 있을까요? 문영민 기사입니다. 2010년 출시 이후 5천만 명의 이용자를 확보하며 국민 메신저에 등극한 카카오톡. 올해로 15주년을 맞은 가운데 역대급 규모의 서비스 개편이 진행됩니다.이 정도 규모의 변화는 카카오톡 역사상 처음 있는 일이라 이번 개편은 사용자의 목소리와 행동에 주목하면서 시대의 변화에 민첩하게 대응하 가장 큰 변화는 다음 달부터 채팅탭에 오픈 AI의 채 GPT가 들어오는 겁니다. 최신 모델 GPT 5가 탑재되는데 체 G지pt에서 제공 중인 검색과 이미지 생성 기능 등을 카카오톡에서도 동일하게 사용할 수 있게 됩니다. 채팅탭엔 카카오가 자체 개발한 AI 모델 카나 역시 녹가듭니다. 이용자의 카카오톡 대화 상황을 이해한 뒤 이용자에게 먼저 메시지를 보내 일정 관리와 보이스톡 요약 등의 서비스를 제공합니다. 이번 카카오톡 개편에서 눈에 띄는 또 다른 변화는 기존 전화번호부 형태였던 친구 탭이 피드 형태로 바뀐다는 겁니다. 친구들의 프로필 변경 내역과 발행 콘텐츠 등을 인스타그램과 페이스북처럼 모아서 보여주는 피드식 타임라인으로 제공하는 겁니다. 카카오톡은 4년 사이 두시간 가량 감소한 1인당 월평균 체류 시간을 다시 끌어올릴 수 있을 걸로 기대했습니다. 다만 앞서 지난 10일 네이버도 블로그를 피드형으로 개편했지만 일부 이용자들의 불만이 나오기도 한만큼 무조건적인 성공을 장담할 순 없습니다. 이번 개편으로 카카오 톡에 단순 메신저에서 벗어나 SNS 역할까지 하는 일명 슈퍼앱으로 진화할 수 있을지 관심이 쏠립니다. 연합뉴스 TV 문혁민입니다. 어, 주제를 바꿔서요. 저희가 이번 주에 카카오톡 관련된 얘기를 조금 하고 있거든요. 카카오톡이 실제로 그 업그레이 업데이트가 그래서 됐어요. 혹시 하셨는지요? 네. 아, 저는 글쎄요. 전 나이가 있어서 그런지 저한테 업데이트 하라고 내용이 안 날라오더라고요. 아. 아, 그렇습니까? 지금 그 앱스토어 등에서 업데이트를 하신 분도 계시고 아직 안 하신 분도 계시는데 반응은 조금 안 좋은 거 같은데 어떻습니까? 네. 이게 업데이트가요. 아마 그러실 겁니다. 저처럼. 어, 나는 업데이트 안 돼 있는데 보실 텐데 이게 순차적으로 지금 진행되고 있거든요. 자, 다 되진 않습니다. 그래서 순차적으로 진행되고 있어서 저도 이제 현재는 업데이트가 안 된 상태인데 근데 이제는 네티즌들이나 아니면은 지금 인터넷 누리꾼들의 그 얘기를 이제 종합해 보면 정보를 정확해 보면 너무 불편하다 이런 얘기를 많이 하십니다. 그런 이유가 이미 경험하신 분들은 아시겠지만 이게 목차 순서대로 그니까 친구가 이제 목록화서 나왔다가 지금은 SNS 이제 소셜 기능으로 되다 보니까 그 친구의 이제 일상이 보여진다는 거죠. 피드 영세로 바뀌었기 때문에. 그니까 이게 굉장히 부담된다라는 분도 굉장히 많습니다. 그래서 지금 일각에서는 업데이트 안 받는 방법 이게 지금 인터넷상에서 유행이 되고 있어요. 그래서 자동 업데이트 기능을 아예 꺼 놓는 거죠. 예, 저도 찾아봤는데 의외로 쉽더라고요. 그렇다고 방송에서 알려줄 순 없는 거고 어쨌든간에 자동 업데이트를 안 하게끔 하시는 분들이 점점 더 늘어나고 있습니다. 이런 점들이 아마 카카오 톡에서 아마 고려야 될 부분이 아닐까? 왜 이런 현상이 일어나는지 아마 고려하지 않을까 좀 생각을 해 보겠습니다. 예. 그리고 또 하나 눈에 띄는 건 카카오톡에 채지도 탑재가 된다고 하는데 사실 많이 쓴다곤 하지만 아직도이 채지T가 어려우신 분들도 있을 거거든요. 이게 좀 언젠가는 좀 이게 적응이 되겠죠. 네. 그니까 저는 최 GPT를 유료로 쓰고 있는데 한번 써보다가요. 그러면 이제 유료를 탈퇴할 고민도 한번 해 볼 생각이 있습니다. 만약에 지금 만약에 저도 아직 써 보진 않았지만 그 카카오톡 안에서 최 GPT 5가 어 유료처럼 잘 속도가 빨라지고 데이터량이 충분하다 그러면 그러면 저 같은 유료 회원들은 굳이 돈을 내서 쓸 이유가 없어지거든요. 그래서 일단은 굉장한 좋은 기능이 카카오톡 안에 이제 들어왔다라는 거는 분명해 보입니다. 근데 지금 또 일각에서는 또 이런 얘기를 하고 있죠. 많은 분들이 아까 말씀드린 것처럼 이게 메신저로부터 처음 시작했거든요. 카카오톡은 이게 다른 SNS와 다른 점이에요. 다른 SNS는 아시겠지만 인스타 같은 경우에도요. 친구 몇기를 해야 됩니다.  ...
# [{'title': '[뉴스쏙] 카톡 업데이트 "완전 싫어!"…카카오, 개선 방향 발표 / 연합 ...', 'url': 'https://www.youtube.com/watch?v=v4HMe25Z8a0', 'markdown': '!# [[뉴스쏙] 카톡 업데이트 "완전 싫어!"…카카오, 개선 방향 발표 / 연합뉴스TV(YonhapnewsTV)]( Public**Uploaded by**: **Uploaded at**: 2025-09-28T06:01:18-07:00**Published at**: 2025-09-28T06:01:18-07:00**Length**: 01:51:20**Views**: 7263**Likes**: 38**Category**: News & Politics## Description```카카오톡 대개편 이후 이용자들의 혹평이 쏟아지고 1점 리뷰가 속출하자 카카오가 결국 개선 방향을 발표하기로 했습니다. 이용자들은 카카오톡이 메신저 기능에 집중하지 않았다며 이번 업데이트를 강하게 비판했는데요. 예전으로 돌아갈 수 있을까요? 뉴스쏙에서 함께 살펴보시죠.▲"부장님 골프사진 봐야 하나요"…카톡 \'자동 업데이트\' 불만 속출(최덕재 기자)▲"챗GPT 업고 피드형으로"…카톡, 15년 만에 대변신(문형민 기자)▲[경제읽기]대미투자 두고 \'줄다리기\'…바뀐 카카오톡 평가는[출연 : 권혁중 경제평론가]#카카오 #카카오톡 #카톡 #업데이트 #혹평 #망함 #개선방향 #발표 #결국 #메신저 #인스타 #뉴스쏙 #연합뉴스TV ▣ 연합뉴스TV 다큐멘터리 전문 채널 \'다큐디깅\' 구독하기 연합뉴스TV 유튜브 채널 구독 대한민국 뉴스의 시작 연합뉴스TV / Yonhap News TV Transcript카카오톡 업데이트에 대해서 불만을 표출하는 목소리들이 나오고 있습니다. 일부 채팅이 개선됐다는 평가도 있습니다만 변화가 과하단 불만도 허적지 않는데요. 채팅의 영역에서 SNS 영역으로 넘어간 것 아니냐는 건데 카카오도이 부분에 고민이 깊습니다. 최덕자 계좌입니다. 최신 업데이트된 카카오톡을 연이 웬 사진이 큼지막하게 시선을 사로잡습니다. 원한 것도 아닌데 카카오톡 친구의 변경된 프로필 사진이 뜨는 겁니다. 직장 상사나 잘 모르는 사람인 경우도 많아 불편할 수 있는 부분입니다. 현재로선 사진이 이렇게 존재감 있게 등장하는 걸 막을 방법도 마땅찬이다. 온라인 커뮤니티에는 업데이트를 막는 방법을 묻는 글들이 이따라 올라오고 SNS에서도 업데이트를 하지 말라는 조언이 줄습니다. 채팅 플랫폼에 그치지 않고 AI와 SNS를 접목해 변화하겠단 전략이지만 소비자들의 수요 파악이 얼마나 선행됐는지 되물어볼 대목입니다.이 정도 규모의 변화는 카카오톡 역사상 처음 있는 일이라 할 수 있습니다. 시대의 변화에 민첩하게 대응하겠다는 카카오톡의 의지를 담고 있습니다. 반면 필요했던 채팅 기능이 생긴 부분은 있습니다. 오타가 났을 때 쓴 글를 지우지 않아도 수정해 놓을 수 있는 기능이 생겼습니다. 안 읽은 메시지만 모아볼 수 있는 폴더가 생겼고 채 GPT 도입은 긍정적 평가를 얻고 있습니다. 채팅계에서는 일부 긍정적 평가를 받지만 SNS 반영은 부정적인 평가가 줄을 이루면서 카카오는 정체성 무게출을 어디에 둘지 고심하고 있습니다. 카카오 관계자는 목적형 서비스에서 탐색형 서비스로 전환하는 과정이라며 대화를 목적으로 유입된 사용자가 즐길거리나 새로운 정보 같은 새로운 콘텐츠로 이어지게 할 것이라고 설명했습니다. 이어 고객 불만을 접수해 수정해 갈 것이라면서 그동안 카카오톡은 계속 변화해 왔다고 강조했습니다. 연합뉴스 TV 최덕제입니다. 카카오톡이 출시 15년 만에 대변신을 합니다. 채팅에 채 GPT를 탑재하고 인스타그램과 유상한 피드 형식을 도입해서 소셜 커뮤니티 플랫폼으로 영역을 넓힌다는 구상입니다. 경쟁 플랫폼으로 눈을 돌린 이용자들의 마음을 다시 사로잡을 수 있을까요? 문영민 기사입니다. 2010년 출시 이후 5천만 명의 이용자를 확보하며 국민 메신저에 등극한 카카오톡. 올해로 15주년을 맞은 가운데 역대급 규모의 서비스 개편이 진행됩니다.이 정도 규모의 변화는 카카오톡 역사상 처음 있는 일이라 이번 개편은 사용자의 목소리와 행동에 주목하면서 시대의 변화에 민첩하게 대응하 가장 큰 변화는 다음 달부터 채팅탭에 오픈 AI의 채 GPT가 들어오는 겁니다. 최신 모델 GPT 5가 탑재되는데 체 G지pt에서 제공 중인 검색과 이미지 생성 기능 등을 카카오톡에서도 동일하게 사용할 수 있게 됩니다. 채팅탭엔 카카오가 자체 개발한 AI 모델 카나 역시 녹가듭니다. 이용자의 카카오톡 대화 상황을 이해한 뒤 이용자에게 먼저 메시지를 보내 일정 관리와 보이스톡 요약 등의 서비스를 제공합니다. 이번 카카오톡 개편에서 눈에 띄는 또 다른 변화는 기존 전화번호부 형태였던 친구 탭이 피드 형태로 바뀐다는 겁니다. 친구들의 프로필 변경 내역과 발행 콘텐츠 등을 인스타그램과 페이스북처럼 모아서 보여주는 피드식 타임라인으로 제공하는 겁니다. 카카오톡은 4년 사이 두시간 가량 감소한 1인당 월평균 체류 시간을 다시 끌어올릴 수 있을 걸로 기대했습니다. 다만 앞서 지난 10일 네이버도 블로그를 피드형으로 개편했지만 일부 이용자들의 불만이 나오기도 한만큼 무조건적인 성공을 장담할 순 없습니다. 이번 개편으로 카카오 톡에 단순 메신저에서 벗어나 SNS 역할까지 하는 일명 슈퍼앱으로 진화할 수 있을지 관심이 쏠립니다. 연합뉴스 TV 문혁민입니다. 어, 주제를 바꿔서요. 저희가 이번 주에 카카오톡 관련된 얘기를 조금 하고 있거든요. 카카오톡이 실제로 그 업그레이 업데이트가 그래서 됐어요. 혹시 하셨는지요? 네. 아, 저는 글쎄요. 전 나이가 있어서 그런지 저한테 업데이트 하라고 내용이 안 날라오더라고요. 아. 아, 그렇습니까? 지금 그 앱스토어 등에서 업데이트를 하신 분도 계시고 아직 안 하신 분도 계시는데 반응은 조금 안 좋은 거 같은데 어떻습니까? 네. 이게 업데이트가요. 아마 그러실 겁니다. 저처럼. 어, 나는 업데이트 안 돼 있는데 보실 텐데 이게 순차적으로 지금 진행되고 있거든요. 자, 다 되진 않습니다. 그래서 순차적으로 진행되고 있어서 저도 이제 현재는 업데이트가 안 된 상태인데 근데 이제는 네티즌들이나 아니면은 지금 인터넷 누리꾼들의 그 얘기를 이제 종합해 보면 정보를 정확해 보면 너무 불편하다 이런 얘기를 많이 하십니다. 그런 이유가 이미 경험하신 분들은 아시겠지만 이게 목차 순서대로 그니까 친구가 이제 목록화서 나왔다가 지금은 SNS 이제 소셜 기능으로 되다 보니까 그 친구의 이제 일상이 보여진다는 거죠. 피드 영세로 바뀌었기 때문에. 그니까 이게 굉장히 부담된다라는 분도 굉장히 많습니다. 그래서 지금 일각에서는 업데이트 안 받는 방법 이게 지금 인터넷상에서 유행이 되고 있어요. 그래서 자동 업데이트 기능을 아예 꺼 놓는 거죠. 예, 저도 찾아봤는데 의외로 쉽더라고요. 그렇다고 방송에서 알려줄 순 없는 거고 어쨌든간에 자동 업데이트를 안 하게끔 하시는 분들이 점점 더 늘어나고 있습니다. 이런 점들이 아마 카카오 톡에서 아마 고려야 될 부분이 아닐까? 왜 이런 현상이 일어나는지 아마 고려하지 않을까 좀 생각을 해 보겠습니다. 예. 그리고 또 하나 눈에 띄는 건 카카오톡에 채지도 탑재가 된다고 하는데 사실 많이 쓴다곤 하지만 아직도이 채지T가 어려우신 분들도 있을 거거든요. 이게 좀 언젠가는 좀 이게 적응이 되겠죠. 네. 그니까 저는 최 GPT를 유료로 쓰고 있는데 한번 써보다가요. 그러면 이제 유료를 탈퇴할 고민도 한번 해 볼 생각이 있습니다. 만약에 지금 만약에 저도 아직 써 보진 않았지만 그 카카오톡 안에서 최 GPT 5가 어 유료처럼 잘 속도가 빨라지고 데이터량이 충분하다 그러면 그러면 저 같은 유료 회원들은 굳이 돈을 내서 쓸 이유가 없어지거든요. 그래서 일단은 굉장한 좋은 기능이 카카오톡 안에 이제 들어왔다라는 거는 분명해 보입니다. 근데 지금 또 일각에서는 또 이런 얘기를 하고 있죠. 많은 분들이 아까 말씀드린 것처럼 이게 메신저로부터 처음 시작했거든요. 카카오톡은 이게 다른 SNS와 다른 점이에요. 다른 SNS는 아시겠지만 인스타 같은 경우에도요. 친구 몇기를 해야 됩니다.  ...
# ---------- TextMessage (research_analyst) ----------
# # 카카오톡 업데이트 연구보고서
#
# ## Executive Summary
# 이번 연구에서는 2025년 카카오톡의 대규모 업데이트에 대한 사용자 반응과 카카오의 대응 방안을 분석하였다. 카카오톡은 기존 메신저의 기능에서 소셜미디어 및 AI 기능으로의 전환을 시도하였으나, 사용자들은 불만과 혼란을 표출하며 기존의 메신저 본연의 임무를 상실했다고 지적하고 있다. 카카오는 이러한 피드백을 수렴하여 기능 개선을 약속하고 있으나, 향후 방향성에 대한 고민이 필요하다.
#
# ## Background & Current State
# 카카오톡 업데이트는 카카오톡의 출시 15주년을 맞아 진행된 대규모 개편으로, AI 및 소셜미디어 관련 기능을 추가하여 사용자 체류 시간 및 사용성을 증대시키려는 목적을 가지고 있다. 하지만 사용자들은 업데이트 후 UI 변화와 친구 목록 기능의 변경으로 심각한 불편을 겪고 있다고 보고하고 있다.
#
# - 평균 친구 수: 410명
# - 기존 프로필 업데이트 비율: 23%
# - 월평균 체류 시간 감소: 822분(2021년) → 709분(2023년)
#
# ## Analysis & Insights
# - **주요변화**: 카카오톡은 친구 목록을 피드 형태로 전환하고, 사용자 경험을 개선하기 위해 AI 기반 기능인 ‘카나나’를 도입하였다. 그러나 그 과정에서 개인 정보 노출 우려와 소셜미디어화에 대한 반발이 불거졌다.
#
# - **사용자 반응**:
#   - 긍정적: 메시지 수정 기능과 새로운 AI 기능에 대한 호평.
#   - 부정적: 친구 목록의 변화, 사용성이 저하되고 있다는 불만이 많았다.
#
# - **전문가 의견**: 카카오톡이 지속 가능한 플랫폼으로 남기 위해서는 사용자 피드백을 반영하고, 기존 메신저 기능과의 균형을 잡아야 할 필요성이 높아지고 있다.
#
# ## Future Outlook
# - **Emerging Trends**: 카카오는 사용자 피드백에 따라 부분적인 개편을 고려할 예정이다. 특히, 광고 노출 및 피드 기능에서 선택적 사용을 가능하게 하는 방향으로 나아가야 할 것이다.
#
# - **Predictions**: 많은 사용자가 다른 플랫폼으로 이동할 가능성이 있으며, 카카오는 이러한 이탈을 방지하기 위해 기존 기능들을 복구하거나 수정보완하는 방향으로 나아가야 할 것이다.
#
# - **Implications**: 카카오는 광고 수익과 사용자 편의성을 동시에 만족시키는 비즈니스 모델을 찾아야 할 것이며, 지속적인 사용자 소통 및 환경 변화 대응이 필요하다.
#
# ## Sources
# 1. [카카오톡 15년 만 대개편, 사용자 반응 분석 - Goover](https://seo.goover.ai/report/202509/go-public-report-ko-7291cc3a-e47c-41cf-a6ca-885e417d6f31-0-0.html)
# 2. [카카오톡 업데이트 생각보다 더 문제였다 - 네이버 블로그](https://blog.naver.com/redbirdstock/224024037758)
# 3. [“1점도 아깝다…카톡, 돌려놔” 비판 쏟아지는 카카오톡 롤백 나설까 - 서울경제](https://news.nate.com/view/20250928n07886)
# 4. [카카오톡 업데이트, 달라진 점과 사용자 반응 - 티스토리](https://gc5872.tistory.com/entry/%EC%B9%B4%EC%B9%B4%EC%98%A4%ED%86%A1-%EC%97%85%EB%8D%B0%EC%9D%B4%ED%8A%B8-%EB%8B%AC%EB%9D%BC%EC%A7%84-%EC%A0%90%EA%B3%BC-%EC%82%AC%EC%9A%A9%EC%9E%90-%EB%B0%98%EC%9D%91-%EC%97%85%EB%8D%B0%EC%9D%B4%ED%8A%B8-%EC%B7%A8%EC%86%8C-%EB%B0%A9%EB%B2%95)
#
# REPORT_COMPLETE
# ---------- TextMessage (research_enhancer) ----------
# The research is sufficient to proceed with the report.
# ---------- TextMessage (research_analyst) ----------
# # 카카오톡 업데이트 연구보고서
#
# ## Executive Summary
# 이번 연구에서는 2025년 카카오톡의 대규모 업데이트에 대한 사용자 반응과 카카오의 대응 방안을 분석하였다. 카카오톡은 기존 메신저의 기능에서 소셜미디어 및 AI 기능으로의 전환을 시도하였으나, 사용자들은 불만과 혼란을 표출하며 기존의 메신저 본연의 임무를 상실했다고 지적하고 있다. 카카오는 이러한 피드백을 수렴하여 기능 개선을 약속하고 있으나, 향후 방향성에 대한 고민이 필요하다.
#
# ## Background & Current State
# 카카오톡 업데이트는 카카오톡의 출시 15주년을 맞아 진행된 대규모 개편으로, AI 및 소셜미디어 관련 기능을 추가하여 사용자 체류 시간 및 사용성을 증대시키려는 목적을 가지고 있다. 사용자 체류 시간의 감소와 10대~20대의 '탈카톡' 현상이 심화됨에 따라, 카카오는 사용자 경험을 변화시키고자 하였다.
#
# - **프라이버시(node)**: 친구 목록의 피드 형태 전환으로 인해, 무관심한 사람들의 일상도 쉽게 노출될 위험이 존재.
# - **기능 통합**: 메신저 기능과 소셜 미디어 기능의 결합으로 사용자 혼란 초래.
#
# ## Analysis & Insights
# - **주요변화**: 카카오톡은 친구 목록을 피드 형태로 전환하고, 사용자 경험을 개선하기 위해 AI 기반 기능인 ‘카나나’를 도입하였다. 그러나 그 과정에서 개인 정보 노출에 대한 우려와 불만이 제기되고 있다.
#
# - **사용자 반응**:
#   - 긍정적: 메시지 수정 기능과 AI 요약 기능에 대한 호평은 사용자의 편의성을 증대시켰다.
#   - 부정적: 친구 목록의 변화는 사용자들 사이에서 큰 불만을 일으키고 있으며, 이러한 변화가 개인 정보를 침해하는 것 아니냐는 우려의 목소리가 높다.
#
# - **전문가 의견**: 카카오톡이 지속 가능한 플랫폼을 유지하기 위해서는 사용자 피드백을 최대한 반영하고, 기존 메신저 기능과의 균형을 맞추어야 한다.
#
# ## Future Outlook
# - **Emerging Trends**: 카카오는 사용자 피드백에 따라 부분적인 개편을 고려할 예정이다. 특히 광고 노출 및 피드 기능에서 선택적 사용을 가능하게 하는 방향으로 나아가야 할 것이다.
#
# - **Predictions**: 많은 사용자가 다른 플랫폼으로 이동할 가능성이 있으며, 카카오는 이러한 이탈을 방지하기 위해 기존 기능들을 복구하거나 수정보완하는 방향으로 나아가야 할 것이다.
#
# - **Implications**: 카카오는 광고 수익과 사용자 편의성을 동시에 만족시키는 비즈니스 모델을 찾아야 하며, 지속적인 사용자 소통 및 환경 변화 대응이 필요하다.
#
# ## Sources
# 1. [카카오톡 15년 만 대개편, 사용자 반응 분석 - Goover](https://seo.goover.ai/report/202509/go-public-report-ko-7291cc3a-e47c-41cf-a6ca-885e417d6f31-0-0.html)
# 2. [카카오톡 업데이트 생각보다 더 문제였다 - 네이버 블로그](https://blog.naver.com/redbirdstock/224024037758)
# 3. [“1점도 아깝다…카톡, 돌려놔” 비판 쏟아지는 카카오톡 롤백 나설까 - 서울경제](https://news.nate.com/view/20250928n07886)
# 4. [카카오톡 업데이트, 달라진 점과 사용자 반응 - 티스토리](https://gc5872.tistory.com/entry/%EC%B9%B4%EC%B9%B4%EC%98%A4%ED%86%A1-%EC%97%85%EB%8D%B0%EC%9D%B4%ED%8A%B8-%EB%8B%AC%EB%9D%BC%EC%A7%84-%EC%A0%90%EA%B3%BC-%EC%82%AC%EC%9A%A9%EC%9E%90-%EB%B0%98%EC%9D%91-%EC%97%85%EB%8D%B0%EC%9D%B4%ED%8A%B8-%EC%B7%A8%EC%86%8C-%EB%B0%A9%EB%B2%95)
#
# REPORT_COMPLETE
